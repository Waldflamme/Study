# %% [markdown]
# # Семинар 2.2 (4). Многомерные списки
#
# Присвойте этому файлу имя в формате *Фамилия_Имя_Группа_Семинар_4*. Разместите файл в соответствующем разделе электронного учебного курса.

# %% [markdown]
# <p style="background:#F0A5FF; font-weight:bold">Задача 1. Случайная матрица</p>
#
# Создать матрицу $A=(a_{i,j})_{m \times n} $ из $m$ строк и $n$ столбцов $(m=5, n=6)$. Заполнить матрицу случайными целыми числами от -10 до 10. Вывести матрицу на экран. Для созданной матрицы: 1) вычислить количество строк, содержащих нули; 2) проверить, есть ли в исходной матрице одинаковые строки; 3) вычислить транспонированную матрицу; 4) удалить строку и столбец с заданными номерами. Номера строки и столбца вводятся; 5) вставить строку и столбец с заданными номерами. Номера вводятся. Строку и столбец заполнить нулями.

# %%
# 1.

# %% [markdown]
# <p style="background:#F0A5FF; font-weight:bold">Задача 2. Сессия</p>
#
# Результат сессии, состоящей из 3 экзаменов (История, Алгебра, Информатика), для студента задается в виде списка, содержащего фамилию студента и 3 оценки по пятибалльной системе (0-неявка, 2-неудовл., 3-удовл., 4-хорошо, 5-отлично). Результаты группы сохраняются в виде списка списков указанного вида. Для группы выведите на экран: 1) таблицу с результатами экзаменов; 2) фамилии студентов, имеющих задолженности, и названия несданных ими предметов; 3) средний балл по каждой дисциплин; 4) количество неявок, неудовлетворительных, удовлетворительных, хороших и отличных оценок по дисциплине Информатика.

# %%
# 2.

# %% [markdown]
# <p style="background:#F0A5FF; font-weight:bold">Задача 3. Список списков</p>
#
# Задан список с вложенными списками (элементы - числа). Для всех списков с длиной больше 3: оставить только три первых элемента, прибавив к третьему все удаленные элементы. Например, из
#
# ```[[1, 2], [3, 4, 4, 3, 1], [4,1,4,5]]```
#
# получить
#
# ```[[1, 2], [3, 4, 8], [4, 1, 9]]```

# %%
# 3.

# %% [markdown]
# <p style="background:#F0A5FF; font-weight:bold">Задача 4. Матричное произведение</p>
#
# Реализовать умножение двух матриц, записанных как список списков.

# %%
# 4.

# %% [markdown]
# <p style="background:#F899FF; font-weight:bold">Задача 5. Распаковка списка</p>
#
# Используя распаковку, из списка списков сделать список, содержащий последовательность первых и последних значений вложенных списков и сохраняющий порядок их следования. Пример:
# ```
# [[1, 2, 3], [4, 5, 6, 7], [9, 2], [7]] -> [1, 3, 4, 7, 9, 2, 7]
# ```

# %%
# 5.

# %% [markdown]
# <p style="background:#F899FF; font-weight:bold">Задача 6. Дни недели</p>
#
# Создайте матрицу размера 𝑛 × 𝑚 элементами которой являются дни недели, случайно выбранные из списка.

# %%
# 6.

# %% [markdown]
# <p style="background:#F0A5FF; font-weight:bold">Задача 7. Разбиение списков</p>
#
# Дан список $A$, состоящий из $2N$ элементов. Разбейте его на списки $B$ и $C$ по $N$ элементов каждый так, чтобы каждый элемент $B$ не превосходил каждого элемента $C$.

# %%
# 7.

# %% [markdown]
# <p style="background:#F0A5FF; font-weight:bold">Задача 8. Средний элемент</p>
#
# В списке $L$ имеется $2n + 1$ различных элементов. Найдите средний элемент списка. Под средним элементом понимают такой, для которого в списке $n$ элементов больше его и $n$ элементов меньше.

# %% [markdown]
# <p style="background:#F0A5FF; font-weight:bold">Задача 9. Функции</p>
#
# Создать в цикле список значений $x$ от $-\pi$ до $\pi$ (с небольшим произвольным шагом). Для заданного списка рассчитать значения функций
#
# $$f(x) = 2 𝑠𝑖𝑛 (𝑥)$$
# $$f(x) = 𝑐𝑜𝑠 (2𝑥)$$
